# %%
import kagglehub

path = kagglehub.dataset_download("riccardosimionato/optical-dynamic-range-compressors-la-2a-cl-1b")

print("Path to dataset files:", path)
# Out:
# ...
# Download already complete (28621381054 bytes).
# Extracting model files...
# Path to dataset files: /home/yf/.cache/kagglehub/datasets/riccardosimionato/optical-dynamic-range-compressors-la-2a-cl-1b/versions/1
